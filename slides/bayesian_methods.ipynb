# %% [markdown]
# # Bayesian Methods and Generative Models
#
# Machine Learning Fundamentals for Economists
#
# Jesse Perla (University of British Columbia)
#
# # Overview
#
# ## Motivation
#
# -   We spent A LOT of time on auto-diff and optimization
# -   A related set of problems are Bayesian methods which can use
#     gradients for either: (1) MLE/MAP or (2) in the sampling process
#
# ## References
